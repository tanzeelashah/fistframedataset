# %%
import numpy as np

# %%
import pandas as pd

# %%
df =pd .read_csv('fist.dataset.csv')

# %%
df
# Out:
#     unmaed   0  gpa      iq  plament
# 0        0   0  6.8  .123.0        1
# 1        1   1  5.9  .160.0        0
# 2        2   2  5.3  .120.0        0
# 3        3   3  7.4  .132.0        1
# 4        4   4  5.8  .142.0        0
# 5        5   5  3.2  .122.0        0
# 6        6   6  2.1  .131.0        0
# 7        7   7  2.2  .162.0        0
# 8        8   8  4.5  .154.0        0
# 9        9   9  4.3  .167.0        0
# 10      10  10  3.1  .125.0        0
# 11      11  11  3.3  .137.0        0
# 12      12  12  6.1  .156.0        1
# 13      13  13  6.3  .156.0        1
# 14      14  14  6.7  .121.0        1
# 15      15  15  6.4  .153.0        1
# 16      16  16  7.1  .133.0        1
# 17      17  17  7.3  .159.0        1
# 18      18  18  6.5  .158.0        1
# 19      19  19  6.6  .159.0        1
# 20      20  20  3.5  .117.0        0

# %%
df.shape
# Out:
# (21, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   unmaed   21 non-null     int64
#  1   0        21 non-null     int64
#  2   gpa      21 non-null     float64
#  3   iq       21 non-null     object
#  4   plament  21 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 972.0+ bytes

# %%
df = df.iloc[:,1:]

# %%
df
# Out:
#      0  gpa      iq  plament
# 0    0  6.8  .123.0        1
# 1    1  5.9  .160.0        0
# 2    2  5.3  .120.0        0
# 3    3  7.4  .132.0        1
# 4    4  5.8  .142.0        0
# 5    5  3.2  .122.0        0
# 6    6  2.1  .131.0        0
# 7    7  2.2  .162.0        0
# 8    8  4.5  .154.0        0
# 9    9  4.3  .167.0        0
# 10  10  3.1  .125.0        0
# 11  11  3.3  .137.0        0
# 12  12  6.1  .156.0        1
# 13  13  6.3  .156.0        1
# 14  14  6.7  .121.0        1
# 15  15  6.4  .153.0        1
# 16  16  7.1  .133.0        1
# 17  17  7.3  .159.0        1
# 18  18  6.5  .158.0        1
# 19  19  6.6  .159.0        1
# 20  20  3.5  .117.0        0

# %%
import matplotlib .pyplot as plt

# %%
plt.scatter(df['gpa'],df['iq'],df['plament'])

# %%
A = df.iloc[:,0:2]

# %%
A
# Out:
#      0  gpa
# 0    0  6.8
# 1    1  5.9
# 2    2  5.3
# 3    3  7.4
# 4    4  5.8
# 5    5  3.2
# 6    6  2.1
# 7    7  2.2
# 8    8  4.5
# 9    9  4.3
# 10  10  3.1
# 11  11  3.3
# 12  12  6.1
# 13  13  6.3
# 14  14  6.7
# 15  15  6.4
# 16  16  7.1
# 17  17  7.3
# 18  18  6.5
# 19  19  6.6
# 20  20  3.5

# %%
B = df.iloc[:,-1]

# %%
B
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
# 5     0
# 6     0
# 7     0
# 8     0
# 9     0
# 10    0
# 11    0
# 12    1
# 13    1
# 14    1
# 15    1
# 16    1
# 17    1
# 18    1
# 19    1
# 20    0
# Name: plament, dtype: int64

# %%
from sklearn .model_selection import train_test_split

# %%
 A_train,A_test,B_train,B_test= train_test_split(A,B,test_size= 0.1)

# %%
A_train
# Out:
#      0  gpa
# 8    8  4.5
# 18  18  6.5
# 4    4  5.8
# 20  20  3.5
# 13  13  6.3
# 14  14  6.7
# 12  12  6.1
# 6    6  2.1
# 7    7  2.2
# 2    2  5.3
# 15  15  6.4
# 9    9  4.3
# 11  11  3.3
# 16  16  7.1
# 5    5  3.2
# 19  19  6.6
# 0    0  6.8
# 1    1  5.9

# %%
A_test
# Out:
#      0  gpa
# 3    3  7.4
# 17  17  7.3
# 10  10  3.1

# %%
B_train
# Out:
# 8     0
# 18    1
# 4     0
# 20    0
# 13    1
# 14    1
# 12    1
# 6     0
# 7     0
# 2     0
# 15    1
# 9     0
# 11    0
# 16    1
# 5     0
# 19    1
# 0     1
# 1     0
# Name: plament, dtype: int64

# %%
B_test
# Out:
# 3     1
# 17    1
# 10    0
# Name: plament, dtype: int64

# %%
from sklearn .preprocessing import StandardScaler

# %%
scalar = StandardScaler()

# %%
A_train = scalar .fit_transform(A_train)

# %%
A_train
# Out:
# array([[-0.32732684, -0.39990491],
#        [ 1.30930734,  0.84117929],
#        [-0.98198051,  0.40679982],
#        [ 1.63663418, -1.02044701],
#        [ 0.49099025,  0.71707087],
#        [ 0.65465367,  0.96528771],
#        [ 0.32732684,  0.59296245],
#        [-0.65465367, -1.88920595],
#        [-0.49099025, -1.82715174],
#        [-1.30930734,  0.09652877],
#        [ 0.81831709,  0.77912508],
#        [-0.16366342, -0.52401333],
#        [ 0.16366342, -1.14455543],
#        [ 0.98198051,  1.21350455],
#        [-0.81831709, -1.20660964],
#        [ 1.47297076,  0.9032335 ],
#        [-1.63663418,  1.02734192],
#        [-1.47297076,  0.46885403]])

# %%
A_test =scalar.transform(A_test)

# %%
A_test
# Out:
# array([[-1.14564392,  1.39966718],
#        [ 1.14564392,  1.33761297],
#        [ 0.        , -1.26866385]])

# %%
from sklearn .linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
clf.fit(A_train,B_train)
# Out:
# LogisticRegression()

# %%
B_pred = clf .predict(A_test)

# %%
B_test
# Out:
# 3     1
# 17    1
# 10    0
# Name: plament, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(B_test,B_pred)
# Out:
# 1.0
